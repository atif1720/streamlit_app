# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = cv2.imread('Dataflow.png')

# %%
image.shape
# Out:
# (144, 356, 3)

# %%
plt.imshow(image)

# %%
plt.imshow(image_1)

# %%
print(image_1)
# Out:
# None
